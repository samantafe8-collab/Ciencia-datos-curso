# %% [markdown]
# <a href="https://colab.research.google.com/github/samantafe8-collab/Ciencia-datos-curso/blob/main/Primera%20clase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1+1
# Out:
# 2
